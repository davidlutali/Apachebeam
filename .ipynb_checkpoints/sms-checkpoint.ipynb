# %%
import apache_beam as beam
import mysql.connector

# %%
class ReadFromMySQL(beam.DoFn):
    def __init__(self, host, database, user, password, query):
        self.host = host
        self.database = database
        self.user = user
        self.password = password
        self.query = query

    def setup(self):
        # Create a connection to the MySQL database
        self.connection = mysql.connector.connect(
            host=self.host,
            database=self.database,
            user=self.user,
            password=self.password
        )
        self.cursor = self.connection.cursor()

    def process(self, element):
        # Execute the query and yield results row by row
        self.cursor.execute(self.query)
        for row in self.cursor.fetchall():
            yield row

    def teardown(self):
        # Close the database connection
        self.cursor.close()
        self.connection.close()

# %%
from apache_beam.utils.windowed_value import WindowedValue
import apache_beam.transforms.window as window
import re
import json
from collections import Counter

class ParseAndAnalyzeSMS(beam.DoFn):
    def __init__(self):
        self.word_counter = Counter()  # Counter for word frequencies

    def process(self, record):
        # Unpack record fields
        (id, message, sender, recipient, source, sourceID, SMSMessageResponse, 
         createdDt, updateDt, msgResponseID, status, blastID, SMSType) = record

        # Parse the SMSMessageResponse JSON
        process_cost_and_status_data= self.process_cost_and_status()
        # Update word counter with tokenized words from the message
        words = self.tokenize_message(message)
        self.word_counter.update(words)

        # Yield status and cost for the main output
        yield (status, cost)

    @staticmethod
    def tokenize_message(message):
        """Tokenizes a message into words, ignoring punctuation and case."""
        return re.findall(r'\w+', message.lower())

    def finish_bundle(self):
        """
        Emit word count results at the end of the bundle.
        """
        for word, count in self.word_counter.most_common():
            # Emit word count as a tagged output
            yield WindowedValue({"word": word, "count": count}, timestamp=0, windows=[window.GlobalWindow()])


    def process_cost_and_status(sms_response):
        try:
            sms_response = json.loads(SMSMessageResponse)
            cost = float(sms_response["Recipients"][0]["cost"].replace("KES ", ""))
            status = sms_response["Recipients"][0]["status"]
            return [cost, status]
        except (KeyError, ValueError, IndexError, json.JSONDecodeError):
            cost = 0.0
            status = "Unknown"
# Out:
#   Cell In[19], line 17
#     process_cost_and_status_data= self.process_cost_and_status(
#                                                               ^
# SyntaxError: '(' was never closed

# %%
class ParseAndAnalyzeSMS(beam.DoFn):
    def process(self, record):
        # Unpack record fields
        (id, message, sender, recipient, source, sourceID, SMSMessageResponse, 
         createdDt, updateDt, msgResponseID, status, blastID, SMSType) = record

        # Parse the SMSMessageResponse JSON
        try:
            sms_response = json.loads(SMSMessageResponse)
            # Extract the cost from the recipient data
            cost = float(sms_response["Recipients"][0]["cost"].replace("KES ", ""))
            # Extract the status
            status = sms_response["Recipients"][0]["status"]
        except (KeyError, ValueError, IndexError, json.JSONDecodeError):
            # Handle cases where the response cannot be parsed
            cost = 0.0
            status = "Unknown"

        # Yield a tuple of status and cost
        yield (status, cost)

# %%
# Define pipeline options and inputs
pipeline_options = beam.options.pipeline_options.PipelineOptions()
host = "127.0.0.1"
database = 'defaultdb'
user = 'root'
password = 'cypher'
query = 'select * from smslog limit 20000;'

# Pipeline options
#pipeline_options = beam.options.pipeline_options.PipelineOptions()

# Create the pipeline
with beam.Pipeline() as pipeline:
    mysql_data = (
        pipeline
        | "Create Input" >> beam.Create([None])  # Start with an empty input
        | "Read MySQL Data" >> beam.ParDo(ReadFromMySQL(host, database, user, password, query))
        | "Parse and Analyze SMS" >> beam.ParDo(ParseAndAnalyzeSMS())
        | "Group By Status" >> beam.GroupByKey()
        | "Sum Costs Per Status" >> beam.Map(
            lambda status_costs: (status_costs[0], sum(status_costs[1]))
        )
        | "Print Results" >> beam.Map(print)
    )
# Out:
# ('Success', 11773.400000000001)
# ('RejectedByGateway', 0.0)
# ('GatewayError', 0.0)

# %%
# Create the pipeline
with beam.Pipeline() as pipeline:
    analysis = (
        pipeline
        | "Create Input" >> beam.Create([None])  # Start with an empty input
        | "Read MySQL Data" >> beam.ParDo(ReadFromMySQL(host, database, user, password, query))
        | "Parse and Analyze SMS" >> beam.ParDo(ParseAndAnalyzeSMS()).with_outputs("word_counts", main="main")
    )

    # Main output for status and cost analysis
    analysis["main"] | "Print Status and Cost" >> beam.Map(print)
    
    # Word count output for most common words
    analysis["word_counts"] | "Print Word Counts" >> beam.Map(print)
# Out:
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.6)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# ('Success', 0.4)
# {'word': 'your', 'count': 36}
# {'word': '12', 'count': 20}
# {'word': 'has', 'count': 19}
# {'word': 'been', 'count': 19}
# {'word': 'customer', 'count': 16}
# {'word': 'poa', 'count': 13}
# {'word': 'dear', 'count': 11}
# {'word': 'account', 'count': 11}
# {'word': 'renewed', 'count': 10}
# {'word': 'successfully', 'count': 10}
# {'word': 'subscription', 'count': 10}
# {'word': 'expires', 'count': 10}
# {'word': 'on', 'count': 10}
# {'word': '2024', 'count': 10}
# {'word': 'am', 'count': 10}
# {'word': 'keep', 'count': 10}
# {'word': 'it', 'count': 10}
# {'word': '08', 'count': 8}
# {'word': 'ticket', 'count': 6}
# {'word': 'resolved', 'count': 6}
# {'word': 'please', 'count': 6}
# {'word': 'contact', 'count': 6}
# {'word': 'our', 'count': 6}
# {'word': 'care', 'count': 6}
# {'word': 'for', 'count': 6}
# {'word': 'any', 'count': 6}
# {'word': 'queries', 'count': 6}
# {'word': 'password', 'count': 6}
# {'word': 'is', 'count': 5}
# {'word': '00', 'count': 4}
# {'word': 'new', 'count': 3}
# {'word': 'to', 'count': 3}
# {'word': 'pin', 'count': 3}
# {'word': '31', 'count': 2}
# {'word': '03', 'count': 2}
# {'word': 'reset', 'count': 2}
# {'word': 'change', 'count': 2}
# {'word': 'visit', 'count': 2}
# {'word': 'https', 'count': 2}
# {'word': 'support', 'count': 2}
# {'word': 'im', 'count': 2}
# {'word': '06', 'count': 2}
# {'word': '36144', 'count': 1}
# {'word': '35587', 'count': 1}
# {'word': '35711', 'count': 1}
# {'word': 'kelvin', 'count': 1}
# {'word': 'ngisa', 'count': 1}
# {'word': '197855', 'count': 1}
# {'word': 'changed', 'count': 1}
# {'word': '356280', 'count': 1}
# {'word': '35385', 'count': 1}
# {'word': '01', 'count': 1}
# {'word': '35350', 'count': 1}
# {'word': '26971', 'count': 1}
# {'word': 'welcome', 'count': 1}
# {'word': 'street', 'count': 1}
# {'word': 'username', 'count': 1}
# {'word': '0113253329', 'count': 1}
# {'word': 'and', 'count': 1}
# {'word': 'code', 'count': 1}
# {'word': '3209', 'count': 1}
# {'word': '1319', 'count': 1}
# {'word': '04', 'count': 1}
# {'word': '3407', 'count': 1}
